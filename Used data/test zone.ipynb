# %% [markdown]
# This is my testing centre

# %%
import time
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

#from tangle import Tangle, node_graph, watcher, analyser
#from PC_classes import mal_node

# %% [markdown]
# # Different rates

# %%
### Chain 20, different rates
r1 = pd.read_csv("pc-r1-c20 100")
r3 = pd.read_csv("pc-r3-c20 100")
r5 = pd.read_csv("pc-r5-c20 100")
times = []

Nr1 = pd.read_csv("Non-PC-r1 100")
Nr3 = pd.read_csv("Non-PC 100")
Nr5 = pd.read_csv("Non-PC-r5 100")

for n in range(1,61):
    times.append(n)

PCR1 = r1['1'].tolist()[:60]
PCR3 = r3['1'].tolist()[:60]
PCR5 = r5['1'].tolist()[:60]

NPCR1 = Nr1['1'].tolist()[:60]
NPCR3 = Nr3['1'].tolist()[:60]
NPCR5 = Nr5['1'].tolist()[:60]

plt.plot(times, PCR1, label='Chain: Rate = 1', color='b')
plt.plot(times, NPCR1, label='No Chain: Rate = 1', color='b', linestyle='dashed')
plt.plot(times, PCR3, label='Rate = 3', color='g')
plt.plot(times, NPCR3, label='No Chain: Rate = 3', color='g', linestyle='dashed')
plt.plot(times, PCR5, label='Rate = 5', color='r')
plt.plot(times, NPCR5, label='No Chain: Rate = 5', color='r', linestyle='dashed')
plt.legend()
plt.xlabel('Time')
plt.ylabel('Number of confirmations')
plt.title('Different λ values for Chain Length 20')
# Out:
# Text(0.5, 1.0, 'Different λ values for Chain Length 20')

# %%
### Chain 10, different rates
r1 = pd.read_csv("pc-r1-c10 100")
r3 = pd.read_csv("pc-r3-c10 100")
r5 = pd.read_csv("pc-r5-c10 100")
times = []

Nr1 = pd.read_csv("Non-PC-r1 100")
Nr3 = pd.read_csv("Non-PC 100")
Nr5 = pd.read_csv("Non-PC-r5 100")

for n in range(1,61):
    times.append(n)

PCR1 = r1['1'].tolist()[:60]
PCR3 = r3['1'].tolist()[:60]
PCR5 = r5['1'].tolist()[:60]

NPCR1 = Nr1['1'].tolist()[:60]
NPCR3 = Nr3['1'].tolist()[:60]
NPCR5 = Nr5['1'].tolist()[:60]

plt.plot(times, PCR1, label='Chain: Rate = 1', color='b')
plt.plot(times, NPCR1, label='No Chain: Rate = 1', color='b', linestyle='dashed')
plt.plot(times, PCR3, label='Rate = 3', color='g')
plt.plot(times, NPCR3, label='No Chain: Rate = 3', color='g', linestyle='dashed')
plt.plot(times, PCR5, label='Rate = 5', color='r')
plt.plot(times, NPCR5, label='No Chain: Rate = 5', color='r', linestyle='dashed')
plt.legend()
plt.xlabel('Time')
plt.ylabel('Number of confirmations')
plt.title('Different λ values for Chain Length 10')
# Out:
# Text(0.5, 1.0, 'Different λ values for Chain Length 10')

# %%
### Chain 5, different rates
r1 = pd.read_csv("pc-r1-c5 100")
r3 = pd.read_csv("pc-r3-c5 100")
r5 = pd.read_csv("pc-r5-c5 100")
times = []

Nr1 = pd.read_csv("Non-PC-r1 100")
Nr3 = pd.read_csv("Non-PC 100")
Nr5 = pd.read_csv("Non-PC-r5 100")

for n in range(1,61):
    times.append(n)

PCR1 = r1['1'].tolist()[:60]
PCR3 = r3['1'].tolist()[:60]
PCR5 = r5['1'].tolist()[:60]

NPCR1 = Nr1['1'].tolist()[:60]
NPCR3 = Nr3['1'].tolist()[:60]
NPCR5 = Nr5['1'].tolist()[:60]

plt.plot(times, PCR1, label='Chain: Rate = 1', color='b')
plt.plot(times, NPCR1, label='No Chain: Rate = 1', color='b', linestyle='dashed')
plt.plot(times, PCR3, label='Rate = 3', color='g')
plt.plot(times, NPCR3, label='No Chain: Rate = 3', color='g', linestyle='dashed')
plt.plot(times, PCR5, label='Rate = 5', color='r')
plt.plot(times, NPCR5, label='No Chain: Rate = 5', color='r', linestyle='dashed')
plt.legend()
plt.xlabel('Time')
plt.ylabel('Number of confirmations')
plt.title('Different λ values for Chain Length 5')
# Out:
# Text(0.5, 1.0, 'Different λ values for Chain Length 5')

# %%
### Chain 5, different rates
r1 = pd.read_csv("pc-r1-c5 100")
r3 = pd.read_csv("pc-r1-c10 100")
r5 = pd.read_csv("pc-r1-c20 100")
times = []

Nr1 = pd.read_csv("Non-PC-r1 100")
#Nr3 = pd.read_csv("Non-PC 100")
#Nr5 = pd.read_csv("Non-PC-r5 100")

for n in range(1,61):
    times.append(n)

PCR1 = r1['1'].tolist()[:60]
PCR3 = r3['1'].tolist()[:60]
PCR5 = r5['1'].tolist()[:60]

NPCR1 = Nr1['1'].tolist()[:60]
#NPCR3 = Nr3['1'].tolist()[:60]
#NPCR5 = Nr5['1'].tolist()[:60]

plt.plot(times, PCR1, label='Chain Length = 5', color='b')
plt.plot(times, PCR3, label='Chain Length = 10', color='g')
plt.plot(times, PCR5, label='Chain Length = 20', color='r')
plt.plot(times, NPCR1, label='No Chain', color='y', linestyle='dashed')
plt.legend()
plt.xlabel('Time')
plt.ylabel('Number of confirmations')
plt.title('Different Chain Lengths for λ = 1 ')
# Out:
# Text(0.5, 1.0, 'Different Chain Lengths for λ = 1 ')

# %% [markdown]
# # Different Chain Lengths

# %%
### rate 3, different chain lengths
r1 = pd.read_csv("pc-r3-c5 100")
r3 = pd.read_csv("pc-r3-c10 100")
r5 = pd.read_csv("pc-r3-c20 100")
times = []

#Nr1 = pd.read_csv("Non-PC-r1 100")
Nr3 = pd.read_csv("Non-PC 100")
#Nr5 = pd.read_csv("Non-PC-r5 100")

for n in range(1,61):
    times.append(n)

PCR1 = r1['1'].tolist()[:60]
PCR3 = r3['1'].tolist()[:60]
PCR5 = r5['1'].tolist()[:60]

#NPCR1 = Nr1['1'].tolist()[:60]
NPCR3 = Nr3['1'].tolist()[:60]
#NPCR5 = Nr5['1'].tolist()[:60]

plt.plot(times, PCR1, label='Chain Length 5', color='b')
#plt.plot(times, NPCR1, label='No Chain: Rate = 1', color='b', linestyle='dashed')
plt.plot(times, PCR3, label='Chain Length 10', color='g')
plt.plot(times, PCR5, label='Chain Length 20', color='r')
plt.plot(times, NPCR3, label='No Chain', color='y')
#plt.plot(times, NPCR5, label='No Chain: Rate = 5', color='r', linestyle='dashed')
plt.legend()
plt.xlabel('Time')
plt.ylabel('Number of confirmations')
plt.title('Differing Chain Lengths')
# Out:
# Text(0.5, 1.0, 'Differing Chain Lengths')

# %%
### rate 1, different chain lengths
r1 = pd.read_csv("pc-r1-c5 100")
r3 = pd.read_csv("pc-r1-c10 100")
r5 = pd.read_csv("pc-r1-c20 100")
times = []

Nr1 = pd.read_csv("Non-PC-r1 100")
#Nr3 = pd.read_csv("Non-PC 100")
#Nr5 = pd.read_csv("Non-PC-r5 100")

for n in range(1,61):
    times.append(n)

PCR1 = r1['1'].tolist()[:60]
PCR3 = r3['1'].tolist()[:60]
PCR5 = r5['1'].tolist()[:60]

NPCR1 = Nr1['1'].tolist()[:60]
#NPCR3 = Nr3['1'].tolist()[:60]
#NPCR5 = Nr5['1'].tolist()[:60]

plt.plot(times, PCR1, label='Chain Length 5', color='b')
plt.plot(times, NPCR1, label='No Chain', color='y')
plt.plot(times, PCR3, label='Chain Length 10', color='g')
#plt.plot(times, NPCR3, label='No Chain', color='y')
plt.plot(times, PCR5, label='Chain Length 20', color='r')
#plt.plot(times, NPCR5, label='No Chain: Rate = 5', color='r', linestyle='dashed')
plt.legend()
plt.xlabel('Time')
plt.ylabel('Number of confirmations')
plt.title('Differing Chain Lengths Rate 1')
# Out:
# Text(0.5, 1.0, 'Differing Chain Lengths Rate 1')

# %%
### rate 5, different chain lengths
r1 = pd.read_csv("pc-r5-c5 100")
r3 = pd.read_csv("pc-r5-c10 100")
r5 = pd.read_csv("pc-r5-c20 100")
times = []

#Nr1 = pd.read_csv("Non-PC-r1 100")
#Nr3 = pd.read_csv("Non-PC 100")
Nr5 = pd.read_csv("Non-PC-r5 100")

for n in range(1,61):
    times.append(n)

PCR1 = r1['1'].tolist()[:60]
PCR3 = r3['1'].tolist()[:60]
PCR5 = r5['1'].tolist()[:60]

#NPCR1 = Nr1['1'].tolist()[:60]
#NPCR3 = Nr3['1'].tolist()[:60]
NPCR5 = Nr5['1'].tolist()[:60]

plt.plot(times, PCR1, label='Chain Length 5', color='b')
#plt.plot(times, NPCR1, label='No Chain', color='y')
plt.plot(times, PCR3, label='Chain Length 10', color='g')
#plt.plot(times, NPCR3, label='No Chain', color='y')
plt.plot(times, PCR5, label='Chain Length 20', color='r')
plt.plot(times, NPCR5, label='No Chain', color='y')
plt.legend()
plt.xlabel('Time')
plt.ylabel('Number of confirmations')
plt.title('Differing Chain Lengths Rate 5')
# Out:
# Text(0.5, 1.0, 'Differing Chain Lengths Rate 5')

# %% [markdown]
# # Different Attachment Times

# %%
### Chain 20, different attachment times
a1 = pd.read_csv("pc-r3-c20 100")
a2 = pd.read_csv("pc-r3-c20-a20 100")
a3 = pd.read_csv("pc-r3-c20-a40 100")
times = []

Nr3 = pd.read_csv("Non-PC 100")

for n in range(1,61):
    times.append(n)

PCR1 = a1['1'].tolist()[:60]
PCR3 = a2['1'].tolist()[:60]
PCR5 = a3['1'].tolist()[:60]

NPCR3 = Nr3['1'].tolist()[:60]

plt.plot(times, PCR1, label='Time = 5', color='b')
plt.plot(times, PCR3, label='Time = 20', color='g')
plt.plot(times, PCR5, label='Time = 40', color='r')
plt.plot(times, NPCR3, label='No Chain', color='y')
plt.legend()
plt.xlabel('Time')
plt.ylabel('Number of confirmations')
plt.title('Different Attachment Times for Chain Length 20')
# Out:
# Text(0.5, 1.0, 'Different Attachment Times for Chain Length 20')

# %%
### Chain 10, different attachment Times

a1 = pd.read_csv("pc-r3-c10 100")
a2 = pd.read_csv("pc-r3-c10-a20 100")
a3 = pd.read_csv("pc-r3-c10-a40 100")
times = []

Nr3 = pd.read_csv("Non-PC 100")

for n in range(1,61):
    times.append(n)

PCR1 = a1['1'].tolist()[:60]
PCR3 = a2['1'].tolist()[:60]
PCR5 = a3['1'].tolist()[:60]

NPCR3 = Nr3['1'].tolist()[:60]

plt.plot(times, PCR1, label='Time = 5', color='b')
plt.plot(times, PCR3, label='Time = 20', color='g')
plt.plot(times, PCR5, label='Time = 40', color='r')
plt.plot(times, NPCR3, label='No Chain', color='y')
plt.legend()
plt.xlabel('Time')
plt.ylabel('Number of confirmations')
plt.title('Different Attachment Times for Chain Length 10')
# Out:
# Text(0.5, 1.0, 'Different Attachment Times for Chain Length 10')

# %%
### Chain 5, different attachment times
a1 = pd.read_csv("pc-r3-c5 100")
a2 = pd.read_csv("pc-r3-c5-a20 100")
a3 = pd.read_csv("pc-r3-c5-a40 100")
times = []

Nr3 = pd.read_csv("Non-PC 100")

for n in range(1,61):
    times.append(n)

PCR1 = a1['1'].tolist()[:60]
PCR3 = a2['1'].tolist()[:60]
PCR5 = a3['1'].tolist()[:60]

NPCR3 = Nr3['1'].tolist()[:60]

plt.plot(times, PCR1, label='Time = 5', color='b')
plt.plot(times, PCR3, label='Time = 20', color='g')
plt.plot(times, PCR5, label='Time = 40', color='r')
plt.plot(times, NPCR3, label='No Chain', color='y')
plt.legend()
plt.xlabel('Time')
plt.ylabel('Number of confirmations')
plt.title('Different Attachment Times for Chain Length 5')
# Out:
# Text(0.5, 1.0, 'Different Attachment Times for Chain Length 5')
