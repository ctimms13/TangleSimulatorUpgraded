# %%
import time
import numpy as np
import matplotlib.pyplot as plt

from tangle import Tangle, node_graph, watcher

plt.rc('axes', labelsize=20)
plt.rc('xtick', labelsize=20)
plt.rc('ytick', labelsize=20)

# %%
t = Tangle(rate=3, tip_selection='mcmc', plot=True)
ng = node_graph(t)
w = watcher(t, ng)
ng.new_node()
ng.new_node()
ng.new_node()
ng.new_node()
# Out:
# First node
# Finished updating
# -------------------
# Nodes RAW [<tangle.node object at 0x0000027CBC32F380>]
# Edges []
# Node IDS [0]
# Weights [[0, 544, 1]]
# Finished updating
# -------------------
# Nodes RAW [<tangle.node object at 0x0000027CBC32F380>, <tangle.node object at 0x0000027CDB5A6D20>]
# Edges [(1, 0)]
# Node IDS [0, 1]
# Weights [[0, 544, 1], [1, 1609, 2]]
# Finished updating
# -------------------
# Nodes RAW [<tangle.node object at 0x0000027CBC32F380>, <tangle.node object at 0x0000027CDB5A6D20>, <tangle.node object at 0x0000027CBC32F3E0>]
# Edges [(1, 0), (2, 1), (2, 0)]
# Node IDS [0, 1, 2]
# Weights [[0, 544, 1], [1, 1609, 2], [2, 994, 3]]
# Finished updating
# -------------------
# Nodes RAW [<tangle.node object at 0x0000027CBC32F380>, <tangle.node object at 0x0000027CDB5A6D20>, <tangle.node object at 0x0000027CBC32F3E0>, <tangle.node object at 0x0000027CBC32F2C0>]
# Edges [(1, 0), (2, 1), (2, 0), (3, 1), (3, 0)]
# Node IDS [0, 1, 2, 3]
# Weights [[0, 544, 1], [1, 1609, 2], [2, 994, 3], [3, 61, 4]]

# %%
ng.plot_graph()

# %%
for j in range(10):
    for i in range(4):
        ng.nodes[i].issue_transaction()
        w.update()
    w.printStats()
# Out:
# --------------
# 1
# 5
# --------------
# 1
# 9
# --------------
# 3
# 13
# --------------
# 5
# 17
# --------------
# 8
# 21
# --------------
# 11
# 25
# --------------
# 14
# 29
# --------------
# 16
# 33
# --------------
# 18
# 37
# --------------
# 24
# 41
